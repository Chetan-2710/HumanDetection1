# %%
import cv2
import time
import torch
import socket
import struct
import numpy as np
from utils.general import non_max_suppression, scale_coords
from utils.torch_utils import select_device
from datetime import datetime

# %%
# Load pre-trained YOLOv7 model and set device
device = select_device('0' if torch.cuda.is_available() else 'cpu')
print(device)
model = torch.load('yolov7.pt', map_location=device)['model']
model.eval()
# Out:
# cuda:0
# C:\Users\kolak\AppData\Local\Temp\ipykernel_14700\3291274807.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load('yolov7.pt', map_location=device)['model']
# Model(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (3): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (4): Conv(
#       (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (5): Conv(
#       (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (6): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (7): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (8): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (9): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (10): Concat()
#     (11): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (12): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (13): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (14): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (15): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (16): Concat()
#     (17): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (18): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (19): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (20): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (21): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (22): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (23): Concat()
#     (24): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (25): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (26): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (27): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (28): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (29): Concat()
#     (30): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (31): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (32): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (33): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (34): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (35): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (36): Concat()
#     (37): Conv(
#       (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (38): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (39): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (40): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (41): Conv(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (42): Concat()
#     (43): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (44): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (45): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (46): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (47): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (48): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (49): Concat()
#     (50): Conv(
#       (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (51): SPPCSPC(
#       (cv1): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv3): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv4): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (m): ModuleList(
#         (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#         (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#       )
#       (cv5): Conv(
#         (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv6): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv7): Conv(
#         (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#     )
#     (52): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (53): Upsample(scale_factor=2.0, mode='nearest')
#     (54): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (55): Concat()
#     (56): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (57): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (58): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (59): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (60): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (61): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (62): Concat()
#     (63): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (64): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (65): Upsample(scale_factor=2.0, mode='nearest')
#     (66): Conv(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (67): Concat()
#     (68): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (69): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (70): Conv(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (71): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (72): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (73): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (74): Concat()
#     (75): Conv(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (76): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (77): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (78): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (79): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (80): Concat()
#     (81): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (82): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (83): Conv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (84): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (85): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (86): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (87): Concat()
#     (88): Conv(
#       (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (89): MP(
#       (m): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (90): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (91): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (92): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (93): Concat()
#     (94): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (95): Conv(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (96): Conv(
#       (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (97): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (98): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (99): Conv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (100): Concat()
#     (101): Conv(
#       (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (102): RepConv(
#       (act): SiLU()
#       (rbr_dense): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#       (rbr_1x1): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#     )
#     (103): RepConv(
#       (act): SiLU()
#       (rbr_dense): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#       (rbr_1x1): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#     )
#     (104): RepConv(
#       (act): SiLU()
#       (rbr_dense): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#       (rbr_1x1): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       )
#     )
#     (105): Detect(
#       (m): ModuleList(
#         (0): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 255, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# )

# %%
def preprocess_image(img, img_size=640):
    # Get original image dimensions
    h, w = img.shape[:2]
    
    # Calculate the resize ratio while keeping aspect ratio
    scale = min(img_size / h, img_size / w)
    
    # Calculate new dimensions
    new_w, new_h = int(w * scale), int(h * scale)
    
    # Resize image
    img_resized = cv2.resize(img, (new_w, new_h))  # Resize keeping aspect ratio
    
    # Padding to fit img_size if needed (to make the image square)
    top_pad = (img_size - new_h) // 2
    bottom_pad = img_size - new_h - top_pad
    left_pad = (img_size - new_w) // 2
    right_pad = img_size - new_w - left_pad
    
    # Pad the resized image with zeros (black pixels)
    img_resized = cv2.copyMakeBorder(img_resized, top_pad, bottom_pad, left_pad, right_pad, cv2.BORDER_CONSTANT, value=(0, 0, 0))
    
    # Convert BGR to RGB and HWC to CHW format for PyTorch
    img_resized = img_resized[:, :, ::-1].transpose(2, 0, 1)
    img_resized = np.ascontiguousarray(img_resized)
    
    # Normalize to 0-1
    img_resized = torch.from_numpy(img_resized).float() / 255.0
    
    # Add batch dimension
    if img_resized.ndimension() == 3:
        img_resized = img_resized.unsqueeze(0)

    return img_resized

# %%
def detect_humans(image, model, device, img_size=640, conf_thresh=0.25, iou_thresh=0.45):
    # Preprocess image
    img_preprocessed = preprocess_image(image, img_size).to(device)
    
    # Check if the model is using half precision and adjust input
    if next(model.parameters()).dtype == torch.float16:
        img_preprocessed = img_preprocessed.half()  # Convert image to half precision

    with torch.no_grad():
        pred = model(img_preprocessed)[0]  # Run inference
    
    # Apply non-max suppression to filter out multiple detections
    pred = non_max_suppression(pred, conf_thresh, iou_thresh, classes=[0])  # Class 0 is humans
    
    return pred

# %%
def plot_detections(image, predictions, img_size=640):
    img_copy = image.copy()
    h, w = img_copy.shape[:2]  # Get original image dimensions

    for det in predictions:
        if len(det):
            # Convert from normalized coordinates back to original image coordinates
            det[:, :4] = scale_coords((img_size, img_size), det[:, :4], img_copy.shape).round()
            for *xyxy, conf, cls in det:
                # Draw bounding box
                cv2.rectangle(img_copy, (int(xyxy[0]), int(xyxy[1])), (int(xyxy[2]), int(xyxy[3])), (255, 0, 0), 2)
                cv2.putText(img_copy, f'Person {conf:.2f}', (int(xyxy[0]), int(xyxy[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

    return img_copy

# %%
# Function to calculate the center of a bounding box
def calculate_bbox_center(x1, y1, x2, y2):
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2
    return center_x, center_y

def calculate_direction(center_x, center_y, frame_center_x, frame_center_y, x1, y1, x2, y2):
    instructions = []

    # Check if the frame center lies inside the bounding box
    if x1 <= frame_center_x <= x2 and y1 <= frame_center_y <= y2:
        instructions.append("Centered")
    else:
        # Horizontal adjustment
        if frame_center_x < x1:
            instructions.append("Move Right")
        elif frame_center_x > x2:
            instructions.append("Move Left")

        # Forward/Backward adjustment
        if frame_center_y < y1:
            instructions.append("Move Forward")
        elif frame_center_y > y2:
            instructions.append("Move Backward")

    return ", ".join(instructions)

# %%
# Capture video feed from the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video source.")
    exit()

# %%
# Process the video feed frame by frame
while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Get the dimensions of the frame
    frame_height, frame_width = frame.shape[:2]
    frame_center_x = frame_width // 2
    frame_center_y = frame_height // 2

    # Run human detection on the current frame
    predictions = detect_humans(frame, model, device)

    num_people = 0
    closest_person = None
    closest_distance = float('inf')

    for det in predictions:
        for *xyxy, conf, cls in det:
            if conf.item() >= 0.5:
                num_people += 1

                # Extract bounding box coordinates
                x1, y1, x2, y2 = map(int, xyxy)

                # Calculate bounding box center
                bbox_center_x, bbox_center_y = calculate_bbox_center(x1, y1, x2, y2)

                # Calculate distance from frame center to bounding box center
                distance = ((bbox_center_x - frame_center_x) ** 2 + (bbox_center_y - frame_center_y) ** 2) ** 0.5

                # Update closest person if necessary
                if distance < closest_distance:
                    closest_distance = distance
                    closest_person = (bbox_center_x, bbox_center_y, x1, y1, x2, y2)
    print(num_people)
    if closest_person:
        bbox_center_x, bbox_center_y, x1, y1, x2, y2 = closest_person
        direction = calculate_direction(bbox_center_x, bbox_center_y, frame_center_x, frame_center_y,x1,y1,x2,y2)
        print(f"Closest Person at ({bbox_center_x}, {bbox_center_y}): {direction}")
    else:
        print("No humans detected.")

    # Plot detections on the frame
    frame_with_detections = plot_detections(frame, predictions)

    # Display the frame with detections
    cv2.imshow('YOLOv7 Human Detection', frame_with_detections)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Exiting live feed")
        break

# Release the video capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 1
# Closest Person at (346, 390): Centered
# 1
# Closest Person at (346, 390): Centered
# 1
# Closest Person at (345, 390): Centered
# 1
# Closest Person at (346, 391): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (346, 390): Centered
# 1
# Closest Person at (347, 391): Centered
# 1
# Closest Person at (346, 391): Centered
# 1
# Closest Person at (346, 391): Centered
# 1
# Closest Person at (347, 391): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 391): Centered
# 1
# Closest Person at (348, 391): Centered
# 1
# Closest Person at (348, 391): Centered
# 1
# Closest Person at (349, 391): Centered
# 1
# Closest Person at (349, 391): Centered
# 1
# Closest Person at (349, 390): Centered
# 1
# Closest Person at (348, 391): Centered
# 1
# Closest Person at (348, 391): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (347, 391): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (349, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (350, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (349, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (348, 390): Centered
# 1
# Closest Person at (348, 391): Centered
# 1
# Closest Person at (347, 390): Centered
# 1
# Closest Person at (345, 391): Centered
# 1
# Closest Person at (346, 391): Centered
# 1
# Closest Person at (347, 391): Centered
# 1
# Closest Person at (348, 391): Centered
# 1
# Closest Person at (347, 391): Centered
# 1
# Closest Person at (346, 391): Centered
# 1
# Closest Person at (343, 391): Centered
# 1
# Closest Person at (345, 391): Centered
# 1
# Closest Person at (345, 392): Centered
# 1
# Closest Person at (346, 392): Centered
# 1
# Closest Person at (347, 392): Centered
# 1
# Closest Person at (347, 392): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (344, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (345, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (346, 394): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (348, 394): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (346, 394): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (346, 394): Centered
# 1
# Closest Person at (345, 394): Centered
# 1
# Closest Person at (345, 394): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (346, 394): Centered
# 1
# Closest Person at (345, 394): Centered
# 1
# Closest Person at (345, 394): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (345, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (348, 393): Centered
# 1
# Closest Person at (345, 393): Centered
# 1
# Closest Person at (345, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (345, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (346, 394): Centered
# 1
# Closest Person at (346, 394): Centered
# 1
# Closest Person at (345, 393): Centered
# 1
# Closest Person at (348, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (348, 393): Centered
# 1
# Closest Person at (347, 393): Centered
# 1
# Closest Person at (348, 394): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (348, 394): Centered
# 1
# Closest Person at (348, 394): Centered
# 1
# Closest Person at (348, 394): Centered
# 1
# Closest Person at (344, 393): Centered
# 1
# Closest Person at (346, 393): Centered
# 1
# Closest Person at (348, 393): Centered
# 1
# Closest Person at (347, 394): Centered
# 1
# Closest Person at (344, 393): Centered
# 1
# Closest Person at (345, 393): Centered
# 1
# Closest Person at (344, 393): Centered
# 1
# Closest Person at (344, 393): Centered
# 1
# Closest Person at (341, 392): Centered
# 1
# Closest Person at (338, 392): Centered
# 1
# Closest Person at (338, 391): Centered
# 1
# Closest Person at (337, 391): Centered
# 1
# Closest Person at (338, 391): Centered
# 1
# Closest Person at (334, 390): Centered
# 1
# Closest Person at (329, 389): Centered
# 1
# Closest Person at (329, 389): Centered
# 1
# Closest Person at (331, 389): Centered
# 1
# Closest Person at (341, 390): Centered
# 1
# Closest Person at (334, 390): Centered
# 1
# Closest Person at (334, 390): Centered
# 1
# Closest Person at (333, 390): Centered
# 1
# Closest Person at (333, 390): Centered
# 1
# Closest Person at (334, 390): Centered
# 1
# Closest Person at (335, 390): Centered
# 1
# Closest Person at (334, 390): Centered
# 1
# Closest Person at (334, 390): Centered
# 1
# Closest Person at (332, 390): Centered
# 1
# Closest Person at (333, 391): Centered
# 1
# Closest Person at (334, 391): Centered
# 1
# Closest Person at (333, 390): Centered
# 1
# Closest Person at (331, 390): Centered
# 1
# Closest Person at (332, 390): Centered
# 1
# Closest Person at (331, 390): Centered
# 1
# Closest Person at (330, 390): Centered
# 1
# Closest Person at (332, 390): Centered
# 1
# Closest Person at (331, 390): Centered
# 1
# Closest Person at (332, 390): Centered
# 1
# Closest Person at (333, 390): Centered
# 1
# Closest Person at (332, 390): Centered
# 1
# Closest Person at (302, 389): Centered
# 1
# Closest Person at (306, 390): Centered
# 1
# Closest Person at (312, 390): Centered
# 1
# Closest Person at (331, 390): Centered
# 1
# Closest Person at (341, 390): Centered
# 1
# Closest Person at (345, 391): Centered
# 1
# Closest Person at (349, 391): Centered
# 1
# Closest Person at (351, 391): Centered
# 1
# Closest Person at (354, 390): Centered
# 1
# Closest Person at (355, 391): Centered
# 1
# Closest Person at (356, 391): Centered
# 1
# Closest Person at (357, 390): Centered
# 1
# Closest Person at (357, 391): Centered
# 1
# Closest Person at (357, 390): Centered
# 1
# Closest Person at (357, 390): Centered
# 1
# Closest Person at (358, 390): Centered
# 1
# Closest Person at (358, 390): Centered
# 1
# Closest Person at (356, 389): Centered
# 1
# Closest Person at (358, 389): Centered
# 1
# Closest Person at (359, 388): Centered
# 1
# Closest Person at (359, 389): Centered
# 1
# Closest Person at (358, 389): Centered
# 1
# Closest Person at (354, 390): Centered
# 1
# Closest Person at (357, 389): Centered
# 1
# Closest Person at (357, 390): Centered
# 1
# Closest Person at (359, 390): Centered
# 1
# Closest Person at (364, 390): Centered
# 1
# Closest Person at (363, 390): Centered
# 1
# Closest Person at (363, 390): Centered
# 1
# Closest Person at (365, 391): Centered
# 1
# Closest Person at (363, 390): Centered
# 1
# Closest Person at (365, 390): Centered
# 1
# Closest Person at (364, 391): Centered
# 1
# Closest Person at (364, 391): Centered
# 1
# Closest Person at (363, 391): Centered
# 1
# Closest Person at (362, 391): Centered
# 1
# Closest Person at (362, 390): Centered
# 1
# Closest Person at (364, 390): Centered
# 1
# Closest Person at (364, 390): Centered
# 1
# Closest Person at (365, 391): Centered
# 1
# Closest Person at (363, 389): Centered
# 1
# Closest Person at (420, 389): Centered
# 1
# Closest Person at (412, 389): Centered
# 1
# Closest Person at (430, 388): Centered
# 1
# Closest Person at (433, 388): Centered
# 2
# Closest Person at (435, 388): Centered
# 2
# Closest Person at (440, 387): Centered
# 2
# Closest Person at (152, 320): Move Left
# 2
# Closest Person at (439, 384): Centered
# 2
# Closest Person at (437, 385): Centered
# 2
# Closest Person at (429, 384): Centered
# 2
# Closest Person at (425, 384): Centered
# 2
# Closest Person at (423, 385): Centered
# 2
# Closest Person at (421, 382): Centered
# 2
# Closest Person at (404, 379): Centered
# 1
# Closest Person at (384, 359): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (305, 339): Centered
# 1
# Closest Person at (314, 328): Centered
# 1
# Closest Person at (314, 327): Centered
# 1
# Closest Person at (316, 323): Centered
# 1
# Closest Person at (314, 321): Centered
# 1
# Closest Person at (326, 321): Centered
# 1
# Closest Person at (315, 318): Centered
# 1
# Closest Person at (311, 329): Centered
# 1
# Closest Person at (328, 330): Centered
# 1
# Closest Person at (327, 331): Centered
# 1
# Closest Person at (326, 330): Centered
# 1
# Closest Person at (333, 329): Centered
# 1
# Closest Person at (332, 329): Centered
# 1
# Closest Person at (324, 329): Centered
# 1
# Closest Person at (316, 327): Centered
# 1
# Closest Person at (315, 328): Centered
# 1
# Closest Person at (316, 327): Centered
# 1
# Closest Person at (315, 327): Centered
# 1
# Closest Person at (315, 327): Centered
# 1
# Closest Person at (317, 327): Centered
# 1
# Closest Person at (316, 328): Centered
# 1
# Closest Person at (322, 332): Centered
# 1
# Closest Person at (326, 333): Centered
# 1
# Closest Person at (325, 333): Centered
# 1
# Closest Person at (329, 333): Centered
# 1
# Closest Person at (330, 333): Centered
# 1
# Closest Person at (332, 335): Centered
# 1
# Closest Person at (330, 335): Centered
# 1
# Closest Person at (330, 336): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (310, 333): Centered
# 1
# Closest Person at (331, 336): Centered
# 1
# Closest Person at (316, 333): Centered
# 1
# Closest Person at (312, 332): Centered
# 1
# Closest Person at (311, 332): Centered
# 1
# Closest Person at (313, 332): Centered
# 1
# Closest Person at (328, 334): Centered
# 1
# Closest Person at (311, 331): Centered
# 1
# Closest Person at (304, 331): Centered
# 1
# Closest Person at (306, 331): Centered
# 1
# Closest Person at (296, 332): Centered
# 1
# Closest Person at (310, 332): Centered
# 1
# Closest Person at (313, 331): Centered
# 1
# Closest Person at (319, 331): Centered
# 1
# Closest Person at (322, 332): Centered
# 1
# Closest Person at (323, 331): Centered
# 1
# Closest Person at (323, 331): Centered
# 1
# Closest Person at (328, 334): Centered
# 1
# Closest Person at (328, 334): Centered
# 1
# Closest Person at (321, 330): Centered
# 1
# Closest Person at (327, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (327, 334): Centered
# 1
# Closest Person at (329, 335): Centered
# 1
# Closest Person at (327, 334): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 334): Centered
# 1
# Closest Person at (327, 334): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (327, 335): Centered
# 1
# Closest Person at (327, 334): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (327, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (322, 331): Centered
# 1
# Closest Person at (327, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 334): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 334): Centered
# 1
# Closest Person at (329, 335): Centered
# 1
# Closest Person at (329, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (329, 335): Centered
# 1
# Closest Person at (329, 335): Centered
# 1
# Closest Person at (329, 335): Centered
# 1
# Closest Person at (329, 334): Centered
# 1
# Closest Person at (328, 334): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (327, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (328, 335): Centered
# 1
# Closest Person at (329, 336): Centered
# 1
# Closest Person at (328, 336): Centered
# 1
# Closest Person at (329, 336): Centered
# 1
# Closest Person at (327, 336): Centered
# 1
# Closest Person at (310, 335): Centered
# 1
# Closest Person at (310, 334): Centered
# 1
# Closest Person at (327, 338): Centered
# 1
# Closest Person at (316, 336): Centered
# 1
# Closest Person at (329, 338): Centered
# 1
# Closest Person at (330, 338): Centered
# 1
# Closest Person at (329, 338): Centered
# 1
# Closest Person at (332, 338): Centered
# 1
# Closest Person at (331, 337): Centered
# 1
# Closest Person at (330, 336): Centered
# 1
# Closest Person at (318, 332): Centered
# 1
# Closest Person at (317, 331): Centered
# 1
# Closest Person at (316, 331): Centered
# 1
# Closest Person at (318, 332): Centered
# 1
# Closest Person at (318, 331): Centered
# 1
# Closest Person at (316, 332): Centered
# 1
# Closest Person at (313, 334): Centered
# 1
# Closest Person at (312, 335): Centered
# 1
# Closest Person at (322, 338): Centered
# 1
# Closest Person at (321, 338): Centered
# 1
# Closest Person at (320, 338): Centered
# 1
# Closest Person at (319, 339): Centered
# 1
# Closest Person at (320, 339): Centered
# 1
# Closest Person at (320, 339): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (319, 338): Centered
# 1
# Closest Person at (243, 336): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (320, 337): Centered
# 1
# Closest Person at (317, 338): Centered
# 1
# Closest Person at (317, 338): Centered
# 1
# Closest Person at (316, 337): Centered
# 1
# Closest Person at (312, 337): Centered
# 1
# Closest Person at (314, 337): Centered
# 1
# Closest Person at (316, 336): Centered
# 1
# Closest Person at (317, 336): Centered
# 1
# Closest Person at (316, 336): Centered
# 1
# Closest Person at (315, 336): Centered
# 1
# Closest Person at (321, 335): Centered
# 1
# Closest Person at (322, 335): Centered
# 1
# Closest Person at (337, 335): Centered
# 1
# Closest Person at (334, 336): Centered
# 1
# Closest Person at (351, 335): Centered
# 1
# Closest Person at (350, 336): Centered
# 1
# Closest Person at (328, 336): Centered
# 1
# Closest Person at (336, 336): Centered
# 1
# Closest Person at (326, 336): Centered
# 1
# Closest Person at (328, 337): Centered
# 1
# Closest Person at (319, 336): Centered
# 1
# Closest Person at (324, 337): Centered
# 1
# Closest Person at (316, 336): Centered
# 2
# Closest Person at (363, 338): Centered
# 2
# Closest Person at (348, 338): Centered
# 1
# Closest Person at (326, 337): Centered
# 1
# Closest Person at (320, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (321, 337): Centered
# 1
# Closest Person at (320, 337): Centered
# 1
# Closest Person at (319, 336): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (241, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (315, 337): Centered
# 1
# Closest Person at (316, 337): Centered
# 1
# Closest Person at (316, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (325, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (320, 337): Centered
# 1
# Closest Person at (319, 338): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (316, 337): Centered
# 1
# Closest Person at (325, 338): Centered
# 1
# Closest Person at (316, 337): Centered
# 1
# Closest Person at (318, 338): Centered
# 1
# Closest Person at (315, 338): Centered
# 1
# Closest Person at (326, 338): Centered
# 1
# Closest Person at (325, 338): Centered
# 1
# Closest Person at (323, 338): Centered
# 1
# Closest Person at (323, 338): Centered
# 1
# Closest Person at (326, 337): Centered
# 1
# Closest Person at (315, 337): Centered
# 1
# Closest Person at (325, 337): Centered
# 1
# Closest Person at (316, 338): Centered
# 1
# Closest Person at (314, 337): Centered
# 1
# Closest Person at (312, 338): Centered
# 1
# Closest Person at (313, 338): Centered
# 1
# Closest Person at (318, 338): Centered
# 1
# Closest Person at (313, 338): Centered
# 1
# Closest Person at (314, 337): Centered
# 1
# Closest Person at (309, 337): Centered
# 1
# Closest Person at (314, 338): Centered
# 1
# Closest Person at (315, 337): Centered
# 1
# Closest Person at (315, 337): Centered
# 1
# Closest Person at (312, 337): Centered
# 1
# Closest Person at (310, 337): Centered
# 1
# Closest Person at (328, 338): Centered
# 1
# Closest Person at (311, 337): Centered
# 0
# No humans detected.
# 1
# Closest Person at (316, 336): Centered
# 1
# Closest Person at (324, 336): Centered
# 1
# Closest Person at (263, 336): Centered
# 1
# Closest Person at (314, 336): Centered
# 1
# Closest Person at (329, 337): Centered
# 1
# Closest Person at (312, 336): Centered
# 1
# Closest Person at (323, 337): Centered
# 1
# Closest Person at (329, 339): Centered
# 1
# Closest Person at (318, 339): Centered
# 1
# Closest Person at (318, 339): Centered
# 1
# Closest Person at (316, 340): Centered
# 1
# Closest Person at (318, 340): Centered
# 1
# Closest Person at (317, 339): Centered
# 1
# Closest Person at (318, 341): Centered
# 1
# Closest Person at (317, 340): Centered
# 1
# Closest Person at (317, 339): Centered
# 1
# Closest Person at (319, 340): Centered
# 1
# Closest Person at (318, 340): Centered
# 1
# Closest Person at (317, 340): Centered
# 1
# Closest Person at (317, 340): Centered
# 1
# Closest Person at (316, 342): Centered
# 1
# Closest Person at (316, 341): Centered
# 1
# Closest Person at (316, 342): Centered
# 1
# Closest Person at (315, 343): Centered
# 1
# Closest Person at (316, 343): Centered
# 1
# Closest Person at (316, 344): Centered
# 1
# Closest Person at (317, 344): Centered
# 1
# Closest Person at (317, 345): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (317, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (313, 349): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (313, 348): Centered
# 1
# Closest Person at (314, 348): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (313, 349): Centered
# 1
# Closest Person at (313, 348): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (314, 348): Centered
# 1
# Closest Person at (314, 348): Centered
# 1
# Closest Person at (314, 348): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (314, 348): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (314, 348): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (318, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (313, 349): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (318, 351): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (313, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (313, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (313, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (314, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 351): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (313, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (315, 351): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (313, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (314, 351): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (315, 351): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (315, 351): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (314, 350): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (316, 351): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (315, 351): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (315, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (317, 351): Centered
# 1
# Closest Person at (317, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (316, 350): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (317, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (317, 349): Centered
# 1
# Closest Person at (318, 349): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (315, 349): Centered
# 1
# Closest Person at (316, 349): Centered
# 1
# Closest Person at (315, 348): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (316, 348): Centered
# 1
# Closest Person at (314, 347): Centered
# 1
# Closest Person at (315, 347): Centered
# 1
# Closest Person at (316, 345): Centered
# 1
# Closest Person at (316, 344): Centered
# 1
# Closest Person at (314, 344): Centered
# 1
# Closest Person at (314, 343): Centered
# 1
# Closest Person at (314, 343): Centered
# 1
# Closest Person at (316, 342): Centered
# 1
# Closest Person at (314, 342): Centered
# 1
# Closest Person at (316, 341): Centered
# 1
# Closest Person at (316, 340): Centered
# 1
# Closest Person at (319, 341): Centered
# 1
# Closest Person at (320, 340): Centered
# 1
# Closest Person at (317, 341): Centered
# 1
# Closest Person at (319, 340): Centered
# 1
# Closest Person at (318, 339): Centered
# 1
# Closest Person at (319, 340): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (318, 336): Centered
# 1
# Closest Person at (318, 336): Centered
# 1
# Closest Person at (319, 336): Centered
# 1
# Closest Person at (317, 336): Centered
# 1
# Closest Person at (316, 336): Centered
# 1
# Closest Person at (316, 336): Centered
# 1
# Closest Person at (316, 336): Centered
# 1
# Closest Person at (319, 336): Centered
# 1
# Closest Person at (319, 336): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (317, 336): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (319, 337): Centered
# 1
# Closest Person at (316, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (318, 336): Centered
# 1
# Closest Person at (317, 336): Centered
# 1
# Closest Person at (316, 337): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (320, 337): Centered
# 1
# Closest Person at (317, 338): Centered
# 1
# Closest Person at (318, 337): Centered
# 1
# Closest Person at (317, 337): Centered
# 1
# Closest Person at (326, 339): Centered
# 1
# Closest Person at (317, 338): Centered
# 1
# Closest Person at (320, 337): Centered
# 1
# Closest Person at (317, 338): Centered
# 1
# Closest Person at (319, 338): Centered
# 1
# Closest Person at (318, 338): Centered
# 1
# Closest Person at (319, 338): Centered
# 1
# Closest Person at (321, 339): Centered
# 1
# Closest Person at (321, 337): Centered
# 1
# Closest Person at (321, 338): Centered
# 1
# Closest Person at (320, 337): Centered
# 1
# Closest Person at (323, 337): Centered
# 1
# Closest Person at (322, 337): Centered
# 1
# Closest Person at (322, 337): Centered
# 1
# Closest Person at (322, 337): Centered
# 1
# Closest Person at (321, 336): Centered
# 1
# Closest Person at (322, 337): Centered
# 1
# Closest Person at (321, 337): Centered
# 1
# Closest Person at (324, 337): Centered
# 1
# Closest Person at (324, 337): Centered
# 1
# Closest Person at (328, 337): Centered
# 1
# Closest Person at (325, 337): Centered
# 1
# Closest Person at (325, 338): Centered
# 1
# Closest Person at (324, 337): Centered
# 1
# Closest Person at (323, 337): Centered
# 1
# Closest Person at (325, 337): Centered
# 1
# Closest Person at (324, 338): Centered
# 1
# Closest Person at (325, 338): Centered
# 1
# Closest Person at (327, 338): Centered
# 1
# Closest Person at (326, 338): Centered
# 1
# Closest Person at (328, 338): Centered
# 1
# Closest Person at (328, 338): Centered
# 1
# Closest Person at (330, 338): Centered
# 1
# Closest Person at (330, 338): Centered
# 1
# Closest Person at (330, 338): Centered
# 1
# Closest Person at (331, 338): Centered
# 1
# Closest Person at (328, 338): Centered
# 1
# Closest Person at (327, 339): Centered
# 1
# Closest Person at (321, 338): Centered
# 1
# Closest Person at (322, 338): Centered
# Exiting live feed

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\kolak\AppData\Local\Programs\Python\Python312\python.exe
